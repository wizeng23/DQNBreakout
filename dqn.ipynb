# %% [markdown]
# DQN Notebook

# %%
# %matplotlib inline
# %load_ext autoreload
from train import train_dqn
import pickle

# %%
# %autoreload 2

# %%
env_name = 'BreakoutNoFrameskip-v4'
exp_name = 'dqn'
train_dqn(env_name, exp_name)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/gym/envs/registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)
# Num actions: 4
# Created models
# GPU: Tesla V100-SXM2-16GB
# Initalized models
# Populating replay
# HBox(children=(IntProgress(value=0, description='Populating replay', max=50000), HTML(value='')))
# Starting training
# HBox(children=(IntProgress(value=0, description='Total steps', max=50000000), HTML(value='')))
# Step: 10000
# Average episode reward: 0.2986111111111111
# Loss: 0.0042196848593536946
# Step: 20000
# Average episode reward: 0.2633333333333333
# Loss: 0.0046611459941338276
# Step: 30000
# Average episode reward: 0.25663716814159293
# Loss: 0.004413030364593904
# Step: 40000
# Average episode reward: 0.2621035058430718
# Loss: 0.004234041018713023
# Step: 50000
# Average episode reward: 0.27346938775510204
# Loss: 0.004069768339963555
# Step: 60000
# Average episode reward: 0.2784738041002278
# Loss: 0.003891623613077542
# Step: 70000
# Average episode reward: 0.28158667972575907
# Loss: 0.0035619611890190324
# Step: 80000
# Average episode reward: 0.28356928356928357
# Loss: 0.0033215083308852965
# Step: 90000
# Average episode reward: 0.28451242829827916
# Loss: 0.0032612916684341114
# Step: 100000
# Average episode reward: 0.27829059829059827
# Loss: 0.003237516145338361
# Step: 110000
# Average episode reward: 0.27461300309597525
# Loss: 0.0031456798711816778
# Step: 120000
# Average episode reward: 0.27554796470253345
# Loss: 0.0030889284192447707
# Step: 130000
# Average episode reward: 0.280243000528262
# Loss: 0.003077871935176128
# Step: 140000
# Average episode reward: 0.2786764705882353
# Loss: 0.002988907120538124
# Step: 150000
# Average episode reward: 0.27332576617480137
# Loss: 0.0029002671012187463
# Step: 160000
# Average episode reward: 0.2735788801362572
# Loss: 0.002794261901584012
# Step: 170000
# Average episode reward: 0.2754671488848704
# Loss: 0.002753632573536969
# Step: 180000
# Average episode reward: 0.28134556574923547
# Loss: 0.0027232735729941296
# Step: 190000
# Average episode reward: 0.2825022665457842
# Loss: 0.002654844533177132
# Step: 200000
# Average episode reward: 0.2812392426850258
# Loss: 0.002584301059122644
# Step: 210000
# Average episode reward: 0.2819376026272578
# Loss: 0.0025653372927244194
# Step: 220000
# Average episode reward: 0.2811276429130775
# Loss: 0.002530464762394186
# Step: 230000
# Average episode reward: 0.2800957080903245
# Loss: 0.0024677525281903735
# Step: 240000
# Average episode reward: 0.27987962166809977
# Loss: 0.0024066923503307186
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-737bd4b5669a> in <module>
#       1 env_name = 'BreakoutNoFrameskip-v4'
#       2 exp_name = 'dqn'
# ----> 3 train_dqn(env_name, exp_name)
#
# ~/DQNBreakout/train.py in train_dqn(env_name, save_path)
#      86         last_eps = 0
#      87         if i % P.update_freq == 0:
# ---> 88             loss = compute_loss(replay, optimizer, model, target_model, P.gamma, criterion)
#      89             num_updates += 1
#      90             if num_updates % P.target_update_freq == 0:
#
# ~/DQNBreakout/train.py in compute_loss(replay, optimizer, model, target_model, gamma, criterion)
#     108
#     109 def compute_loss(replay, optimizer, model, target_model, gamma, criterion):
# --> 110     states, actions, rewards, next_states, dones = replay.sample_tensor()
#     111     next_states = next_states
#     112     model_q = model(states) # (batch, actions)
#
# ~/DQNBreakout/utils.py in sample_tensor(self)
#      23
#      24     def sample_tensor(self):
# ---> 25         samples = list(self.sample())
#      26         samples[0] = samples[0].astype(np.float) / 255.0 # states now range (0.0, 1.0)
#      27         samples[3] = samples[3].astype(np.float) / 255.0 # next_states
#
# ~/DQNBreakout/utils.py in sample(self)
#      19     def sample(self):
#      20         samples = random.sample(self.replay, self.batch_size)
# ---> 21         states, actions, rewards, next_states, dones = [np.array(out) for out in zip(*samples)]
#      22         return states, actions, rewards, next_states, dones
#      23
#
# ~/DQNBreakout/utils.py in <listcomp>(.0)
#      19     def sample(self):
#      20         samples = random.sample(self.replay, self.batch_size)
# ---> 21         states, actions, rewards, next_states, dones = [np.array(out) for out in zip(*samples)]
#      22         return states, actions, rewards, next_states, dones
#      23
#
# ~/DQNBreakout/wrappers.py in __len__(self)
#     212         return out
#     213
# --> 214     def __len__(self):
#     215         return len(self._force())
#     216
#
# KeyboardInterrupt:

# %%
loss = pickle.load( open( "experiments/exp/5000_losses.p", "rb" ) )
rewards = pickle.load( open( "experiments/exp/5000_rewards.p", "rb" ) )
print(len(loss))
print(len(rewards))
# Out:
# 146
# 146

# %%
print(sum(loss)/len(loss))
print(sum(rewards)/len(rewards))
# Out:
# 0.0033671895112528955
# 0.2876712328767123
